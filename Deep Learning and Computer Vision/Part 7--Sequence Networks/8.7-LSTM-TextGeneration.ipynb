# %% [markdown]
# # LSTM Text Generation
#
# ### Generate text from existing writings

# %%
'''Example script to generate text from Nietzsche's writings.

At least 20 epochs are required before the generated text
starts sounding coherent.

It is recommended to run this script on GPU, as recurrent
networks are quite computationally intensive.

If you try this script on new data, make sure your corpus
has at least ~100k characters. ~1M is better.
'''

from __future__ import print_function
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys

# %%
path = get_file('nietzsche.txt', origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('corpus length:', len(text))

chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))

print('Vectorization...')
X = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        X[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1


# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars)))
model.add(Activation('softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)


def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)
# Out:
# corpus length: 600901
# total chars: 59
# nb sequences: 200287
# Vectorization...
# Build model...

# %%
# train the model, output generated text after each iteration
for iteration in range(1, 60):
    print()
    print('-' * 50)
    print('Iteration', iteration)
    model.fit(X, y,batch_size=128)

    start_index = random.randint(0, len(text) - maxlen - 1)

    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print()
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x[0, t, char_indices[char]] = 1.

            preds = model.predict(x, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# --------------------------------------------------
# Iteration 1
# 1565/1565 [==============================] - 120s 74ms/step - loss: 2.2851
#
# ----- diversity: 0.2
# ----- Generating with seed: "e
# too-rigid symmetry as intentional and "
# e
# too-rigid symmetry as intentional and the say and the the the the the consince of the really the the the the more the the soul of the prevelves of the soul of the man the manifest of the such the soul of the the something the the the the the the with the the consince of his of the something and the morality of the the the the the the consention of the desing and the resule and the something the power, the the contray the the the mista
#
# ----- diversity: 0.5
# ----- Generating with seed: "e
# too-rigid symmetry as intentional and "
# e
# too-rigid symmetry as intentional and to the stands domain the the great be for and the consifferents, as of how the all the evil of the and the free that have the and himself the consent his beless and not the possons reculted to an conders and to the intelleter in the manifed and one the present of the expression that have and the that a mean of the formen the morality and himself and to him with linger un earts and all the lite and
#
# ----- diversity: 1.0
# ----- Generating with seed: "e
# too-rigid symmetry as intentional and "
# e
# too-rigid symmetry as intentional and pitt of the for this hoully to men almost reperarity, meaning thides, ait time everytapowhers, of defined, beness the
# hascousss
# and
# will powive, of the all apenom hime--inselving always oblife af
# reversifest as been these rigi e's revilieg the condition least its
# lovingms revery all ruspress,, the agains to most, in the lings mys, other is sid actamce. that beor dequiting in now should detesmest l
#
# ----- diversity: 1.2
# ----- Generating with seed: "e
# too-rigid symmetry as intentional and "
# e
# too-rigid symmetry as intentional and veins" dosun--fhatnever. colverneds offul." ofgam tedable action owand iffoct ip.
#   whot in "eriskatited, of an
# the yot fill
# it is naboverly, euson: he abest will make--peshhbouality for natumesh: be m. hith perfimat, heanclings fron anion of ampe to and , geams sysirquent man being grazdacling hewe: that i nwarnce" feom lessa, nature will samon forsiced
# of canted wheth, sprinbfe1ness tecmited, th
#
# --------------------------------------------------
# Iteration 2
# 1565/1565 [==============================] - 110s 70ms/step - loss: 1.6282
#
# ----- diversity: 0.2
# ----- Generating with seed: ". for all religions grew out of dread or"
# . for all religions grew out of dread or a some the conscience and the some to the something and conscience of the so the soul of the some to the still and the some the soul of the so the some to the same the man of the some in the soul of the some the same the something the most and the some and some of the morals and possible the most the some the some to the only the some of the some of his not so the conscience of the some the some
#
# ----- diversity: 0.5
# ----- Generating with seed: ". for all religions grew out of dread or"
# . for all religions grew out of dread or as it is the so the higher real conscience of histortarian and the
# probably and the philosopher to as only the happiness of the called and case and only and sympathy sension, the still not the charay fight son the individual estimation with a soul of schopenhal there is an act hitherto the shight decession of should be doubly great only
# most the so for the sometable
# standard at all the sain to th
#
# ----- diversity: 1.0
# ----- Generating with seed: ". for all religions grew out of dread or"
# . for all religions grew out of dread original
# person to comme, sympatary sertic if no aits, in suched no upon wilorous scientity and dain,  so because favoure, which man natanty
# belief a the ewath ey's deptrons scienceprable, and yet mal, shound poince orden soless of enguil would, auford
# disside is too
# loftly by the phaso) afterwayon your havid in the to most stempring, now himself a responsible, it day itolamingshinanimanity. the alp
#
# ----- diversity: 1.2
# ----- Generating with seed: ". for all religions grew out of dread or"
# . for all religions grew out of dread or greeds divense himself
# a figrt. further truteven and , by divignozound way ave and thereman scomment something, hals, ard which wand coments one his langed otr name--ons it must mespectively condly of mank the such common we has scipnce. the
# cuitl_
# have the
# beliefs to (an ammulical that a goning, and
# angaincing, the ideaby
# of non-thought stiprears sulpower mightacherly yeed, as decessed you quite
#
# --------------------------------------------------
# Iteration 3
# 1565/1565 [==============================] - 118s 76ms/step - loss: 1.5318
#
# ----- diversity: 0.2
# ----- Generating with seed: " to make bad are just as
# little counter-"
#  to make bad are just as
# little counter-conscience in the same the condition of all the sense the self-so all the conscience of the sense in the extinnt in the sense to the self-so the words of the an and the self-soul, and man in the self the sense of the stands of the self-so the power of the power of the self-so the man in the man have a self-man in the self the self-conscience of the power to a stands of the same to the most stands
#
# ----- diversity: 0.5
# ----- Generating with seed: " to make bad are just as
# little counter-"
#  to make bad are just as
# little counter-moderness in reckeserved that it is not in a standing of the miss or and himself, the romething of the highese the self the setsed and altood the himself in milonation of the new the freedom of a possession of stand is the soul, he says the shally will, who formest and believes of all completed the since in the self good in which has place of the more and proment in the render the science and with
#
# ----- diversity: 1.0
# ----- Generating with seed: " to make bad are just as
# little counter-"
#  to make bad are just as
# little counter-men growing moralike upon
# obidial for i moredour of interpretent" couroglifes
# exertarous and learnt even yet imness in gained in the "may be resplatiativelesscefieness and obtriature, considered bycentual the compore--beallatos and
# repedenes, al way the vilops
# of kerme and evolving rommoraniput
# is made that here in the domition to mean, so 1matler. is they orbill, them! when the
# daise even the sec
#
# ----- diversity: 1.2
# ----- Generating with seed: " to make bad are just as
# little counter-"
#  to make bad are just as
# little counter--an ;
# it is reve,
# shies be holoonness of sudseuss righipxers,
# inclase or pleas
# of human man heoconous mannery. to what how incompousfics, explecest,
# shalmosan the old where neral, follition. he lake creach
# goesshands to an estesty enlike him this namopriticheso in a slicken: have that plyer beingstiuc--bud ip to
# ayss whom, ano
# meng anow, will-"zios in bote wither understoul.chy toilakerious
# ma; an
#
# --------------------------------------------------
# Iteration 4
# 1565/1565 [==============================] - 112s 71ms/step - loss: 1.4854
#
# ----- diversity: 0.2
# ----- Generating with seed: "s a determiner of values; he
# does not re"
# s a determiner of values; he
# does not reason and the superiority of the subjective and all the subjective and the superiority and all the strult the sudeent of the present the expease of the superiority and the sumptor of the subjective and the sense of the subjective all the sense of the consequence and all the subjective and the subjective in the consequence of the sudeent of the subject of the superficial such a strongest of the sens
#
# ----- diversity: 0.5
# ----- Generating with seed: "s a determiner of values; he
# does not re"
# s a determiner of values; he
# does not reasons and all being to evil--a result of all and the present the sort and are such or and everything of otherstakes to the satisfard, with the experience of still a consequence of the communical to a transt of the consequently to the realing or the whole beaning that the
# religion of process of intore of all the morality with a plays to the belief of with one will the person "far little to say, and
#
# ----- diversity: 1.0
# ----- Generating with seed: "s a determiner of values; he
# does not re"
# s a determiner of values; he
# does not regrrouseed processish so means of art in fine, the
# souralish beside pry. in made of this vorue-candimes no as a philosophy:
# the bally from                  wheretects to
# deevers, so the religion grows, which learn even as it hi terly speak it belouder :ly continunsuled
# even are
# beculide
# seems of his own in instincts among true recringing,
# and does itself into nollow
# that i course, the
# realipoiss an
#
# ----- diversity: 1.2
# ----- Generating with seed: "s a determiner of values; he
# does not re"
# s a determiner of values; he
# does not religedre itfulter, they thought does: wither order to greatn againing and counity licking asdect; to mugatus
# conseat before if determater-lough
# inscumeed upon and all tendance afterios. a
# a: one in european will used as oppose transence," by the
# occommentleous,
# anacher,
# a
# assey formority to
# it; a ut, they erurare:
# will
# nat in the accecieves or woteven
# teates is its
# surcon:
# we recognsel. mean ventue
#
# --------------------------------------------------
# Iteration 5
# 1565/1565 [==============================] - 123s 79ms/step - loss: 1.4555
#
# ----- diversity: 0.2
# ----- Generating with seed: "rough the opinion of
# others, to attest a"
# rough the opinion of
# others, to attest and sufferer of the sufferer of the sense of the sufferer of the surcended the self-deceive of the sufferer of the sufferer of the suspicion of the sufferer of the sense of the suspicion of the sufferer of the sufferer of the suffering of the sufferer of the soul of the sufferer of the sufferer of the suspicion to the sufferer to the same of the sufferer of the sufferer of the sufferer of the suffe
#
# ----- diversity: 0.5
# ----- Generating with seed: "rough the opinion of
# others, to attest a"
# rough the opinion of
# others, to attest at the prosultion the possession in the end and sufferer of the
# respect of all are sufferion of the suspicate the suspicion is command the sensk of the same
# own philosophical sarder of all the contraric of the soul and conceal histow of man is the means of his enjoyed, on the soul, the possible to his the means of the means of wisher to the spirits possible of the means of the self-menderous the de
#
# ----- diversity: 1.0
# ----- Generating with seed: "rough the opinion of
# others, to attest a"
# rough the opinion of
# others, to attest as in head what the vairace, the
# shador access forl mean the costake with they was are proud even culled as alwayy
# undealeronable necession,
# which is more plain or end which is becamved, once live of unbost such templing idea
#
# men of triated--opcased notly understander easily out the feely sumpled to favour as a syfure evil its posited.
# an probable
# "retraied, all alnories wardsful eviting--we warti
#
# ----- diversity: 1.2
# ----- Generating with seed: "rough the opinion of
# others, to attest a"
# rough the opinion of
# others, to attest also, ally--a heady, to priblures ca quite clise, armundilicumem that can earder
# usexually. a manaricity of raching) in the plavationshard vanity. peep a pationationly becauses? the brances of well floctquesthicuaus begune. "but it stands which--livelimn an swinds--uncloriety of believe feel the mere it here has hitherto crude. untruth of metaphysic demost pains,d, enough he happise". aso-rage, gen
#
# --------------------------------------------------
# Iteration 6
# 1565/1565 [==============================] - 76s 48ms/step - loss: 1.4330
#
# ----- diversity: 0.2
# ----- Generating with seed: "odes of life--like
# the jews, the romans,"
# odes of life--like
# the jews, the romans, the superficial and self-morals and the propert and and the same the soul of the standpring and present the propert to a propert and mo
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-5a6506d3877d> in <module>
#      23                 x[0, t, char_indices[char]] = 1.
#      24
# ---> 25             preds = model.predict(x, verbose=0)[0]
#      26             next_index = sample(preds, diversity)
#      27             next_char = indices_char[next_index]
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1596                         '. Consider setting it to AutoShardPolicy.DATA.')
#    1597
# -> 1598       data_handler = data_adapter.DataHandler(
#    1599           x=x,
#    1600           batch_size=batch_size,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution)
#    1098
#    1099     adapter_cls = select_data_adapter(x, y)
# -> 1100     self._adapter = adapter_cls(
#    1101         x,
#    1102         y,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     317     # trigger the next permutation. On the other hand, too many simultaneous
#     318     # shuffles can contend on a hardware level and degrade all performance.
# --> 319     indices_dataset = indices_dataset.map(permutation).prefetch(1)
#     320
#     321     def slice_batch_indices(indices):
#
# ~\anaconda3\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in map(self, map_func, num_parallel_calls, deterministic)
#    1803     """
#    1804     if num_parallel_calls is None:
# -> 1805       return MapDataset(self, map_func, preserve_cardinality=True)
#    1806     else:
#    1807       return ParallelMapDataset(
#
# ~\anaconda3\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in __init__(self, input_dataset, map_func, use_inter_op_parallelism, preserve_cardinality, use_legacy_function)
#    4206         dataset=input_dataset,
#    4207         use_legacy_function=use_legacy_function)
# -> 4208     variant_tensor = gen_dataset_ops.map_dataset(
#    4209         input_dataset._variant_tensor,  # pylint: disable=protected-access
#    4210         self._map_func.function.captured_inputs,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\ops\gen_dataset_ops.py in map_dataset(input_dataset, other_arguments, f, output_types, output_shapes, use_inter_op_parallelism, preserve_cardinality, name)
#    3018   if tld.is_eager:
#    3019     try:
# -> 3020       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3021         _ctx, "MapDataset", name, input_dataset, other_arguments, "f", f,
#    3022         "output_types", output_types, "output_shapes", output_shapes,
#
# KeyboardInterrupt:
